# %%
# Tạo folder data để các bạn upload file 3 file data được tạo ra ở step 0 vào folder data
# Các bạn upload file hand_gesture.yaml ngoài folder data
# !mkdir data/

# %%
# Nếu đã chạy thành công step 0 thì các bạn không chạy cell này và chỉ upload 3 file data của các bạn vào thư mục data
# Và upload file hand_gesture.yaml bên ngoài thư mục data
# Nếu không chạy được ở step 0 thì các bạn run cell này để download data
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O data/
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O data/
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O data/
# Download file hand_gesture.yam
# !gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu
# To: /Users/hongong/working/aio2024/IoT-Project-Ligh-Controlling-Using-Hand-Guestures/step1_train_classifier/data/landmark_val.csv
# 100%|████████████████████████████████████████| 369k/369k [00:00<00:00, 1.69MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf
# To: /Users/hongong/working/aio2024/IoT-Project-Ligh-Controlling-Using-Hand-Guestures/step1_train_classifier/data/landmark_train.csv
# 100%|██████████████████████████████████████| 1.28M/1.28M [00:00<00:00, 3.21MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq
# To: /Users/hongong/working/aio2024/IoT-Project-Ligh-Controlling-Using-Hand-Guestures/step1_train_classifier/data/landmark_test.csv
# 100%|█████████████████████████████████████████| 320k/320k [00:00<00:00, 990kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# To: /Users/hongong/working/aio2024/IoT-Project-Ligh-Controlling-Using-Hand-Guestures/step1_train_classifier/hand_gesture.yaml
# 100%|███████████████████████████████████████████| 120/120 [00:00<00:00, 462kB/s]

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path, "r") as f:
        label_tag = yaml.full_load(f)["gestures"]
    return label_tag


class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file("hand_gesture.yaml")

        ################## Your Code Here ################## Q1
        """
        Hoàn thành đoạn code để xây dựng một model gồm có 4 hidden layer,
        lần lượng input và output là (63, 128), (128, 128), (128, 128), (128, 128).
        Layer đầu tiên được theo sau bổi một Relu và Batchnorm1d.
        Layer thứ 2, 3, và 4 được theo sau bỏi Relu và Dropout với rate lần lượt là 0.4, 0.4, 0.6.
        Output layer có nhịêm vụ phân loại với input là 128 và output là số lượng class cử chỉ
        """
        ####################################################

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(128, len(list_label)),
        )

    def forward(self, x):
        ################## Your Code Here ################## Q2
        """
        Hoàn thành code để thực hiện forward dự đoán cử chỉ với input x.
        Thực hiệnt flatten x
        Pass x vừa flatten vào linear_relu_stack
        Return  logits (outputs từ layer cuối cùng)
        """
        ####################################################
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

    def predict(self, x, threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob, dim=1)
        return torch.where(softmax_prob[0, chosen_ind] > threshold, chosen_ind, -1)

    def predict_with_known_class(self, x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        return torch.argmax(softmax_prob, dim=1)

    def score(self, logits):
        return -torch.amax(logits, dim=1)

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path, "r") as f:
        label_tag = yaml.full_load(f)["gestures"]
    return label_tag

# %%
class HandLandmarksDetector:
    def __init__(self) -> None:
        self.mp_drawing = mp.solutions.drawing_utils
        self.mp_drawing_styles = mp.solutions.drawing_styles
        self.mp_hands = mp.solutions.hands
        self.detector = self.mp_hands.Hands(
            False, max_num_hands=1, min_detection_confidence=0.5
        )

    def detectHand(self, frame):
        hands = []
        frame = cv2.flip(frame, 1)
        annotated_image = frame.copy()
        results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        if results.multi_hand_landmarks is not None:
            for hand_landmarks in results.multi_hand_landmarks:
                hand = []
                self.mp_drawing.draw_landmarks(
                    annotated_image,
                    hand_landmarks,
                    self.mp_hands.HAND_CONNECTIONS,
                    self.mp_drawing_styles.get_default_hand_landmarks_style(),
                    self.mp_drawing_styles.get_default_hand_connections_style(),
                )
                for landmark in hand_landmarks.landmark:
                    x, y, z = landmark.x, landmark.y, landmark.z
                    hand.extend([x, y, z])
            hands.append(hand)
        return hands, annotated_image

# %%
class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:, 0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(
            self.data.iloc[idx, 1:].to_numpy(dtype=np.float32)
        )
        return torch_data, one_hot_label

# %%
class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")


def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
    # add auroc score
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime("%d-%m %H:%M")
    for epoch in range(300):
        # training step
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(LIST_LABEL), task="MULTICLASS")
        for batch_number, data in enumerate(trainloader):
            inputs, labels = data

            ################## Your Code Here ################## Q9
            """ Hoàn thành code để thực hiện reset gradients và dự đoán class cử
            chỉ của inputs
            """
            optimizer.zero_grad()
            preds = model(inputs)
            ####################################################

            ################## Your Code Here ################## Q10
            """ Hoàn thành code để thực hiện tính loss dưa vào kết quả dự đoán
            và labels, sau đó thực hiện backwward và update parameters thông qua
            optimizer
            """
            loss = loss_function(preds, labels)
            loss.backward()
            optimizer.step()

            ####################################################

            acc_train.update(model.predict_with_known_class(inputs), labels)
            running_loss += loss.item()
        avg_loss = running_loss / len(trainloader)
        # validating step
        model.train(False)
        running_vloss = 0.0
        acc_val = Accuracy(num_classes=len(LIST_LABEL), task="MULTICLASS")
        for i, vdata in enumerate(val_loader):
            vinputs, vlabels = vdata
            preds = model(vinputs)
            vloss = loss_function(preds, vlabels)
            running_vloss += vloss.item()
            acc_val.update(model.predict_with_known_class(vinputs), vlabels)

        # Log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(
            f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}"
        )
        avg_vloss = running_vloss / len(val_loader)
        print("LOSS train {} valid {}".format(avg_loss, avg_vloss))
        print(
            "Training vs. Validation Loss",
            {"Training": avg_loss, "Validation": avg_vloss},
            epoch + 1,
        )
        print(
            "Training vs. Validation accuracy",
            {
                "Training": acc_train.compute().item(),
                "Validation": acc_val.compute().item(),
            },
            epoch + 1,
        )

        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = (
                f"./{save_path}/model_{timestamp}_{model.__class__.__name__}_best"
            )
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            ################## Your Code Here ##################
            # Q5
            """Hoàn thành đoạn code bên dướ để  print ra epoch hiện tại và
            minimum watched metric và thoát loop
            """
            ####################################################
            print(
                f"stopping at epoch {epoch}, minimum: {early_stopper.watched_metrics}"
            )
            break

    model_path = f"./{save_path}/model_{timestamp}_{model.__class__.__name__}_last"
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
DATA_FOLDER_PATH = "./data/"
LIST_LABEL = label_dict_from_config_file("hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH, "landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH, "landmark_val.csv")
save_path = "./models"
os.makedirs(save_path, exist_ok=True)

trainset = CustomImageDataset(train_path)
################## Your Code Here ################## Q3
"""Hoàn thành code để thực hiện khởi tạo DataLoader cho trainset với
batch_size 40 và cho phép xáo trộn
"""
trainloader = torch.utils.data.DataLoader(trainset, batch_size=40, shuffle=True)

####################################################

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset, batch_size=50, shuffle=False)

################## Your Code Here ################## Q8
"""Hoàn thành code để thực hiện khởi tạo NeuralNetwork model đã xây dựng ở trên,
khởi tạo hàm loss sử dụng CrossEntropyLoss và khởi tạo early stopper với patience
là 30 và min_delta là 0.01
"""
model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=30, min_delta=0.01)
####################################################

################## Your Code Here ################## Q4
"""Hoàn thành code để thực hiện cấu hình Adam optimizer cho các tham số của
model với tốc độ học là 0.0001
"""
optimizer = optim.Adam(model.parameters(), lr=0.0001)
####################################################


model, best_model_path = train(
    trainloader, val_loader, model, loss_function, early_stopper, optimizer
)
# Out:
# Epoch 0:
# Accuracy train:0.2276741862297058, val:0.32764506340026855
# LOSS train 1.6114954948425293 valid 1.602625807126363
# Training vs. Validation Loss {'Training': 1.6114954948425293, 'Validation': 1.602625807126363} 1
# Training vs. Validation accuracy {'Training': 0.2276741862297058, 'Validation': 0.32764506340026855} 1
# Epoch 1:
# Accuracy train:0.31599608063697815, val:0.467576801776886
# LOSS train 1.5792714586624732 valid 1.5724123120307922
# Training vs. Validation Loss {'Training': 1.5792714586624732, 'Validation': 1.5724123120307922} 2
# Training vs. Validation accuracy {'Training': 0.31599608063697815, 'Validation': 0.467576801776886} 2
# Epoch 2:
# Accuracy train:0.38076546788215637, val:0.4744027256965637
# LOSS train 1.5579851590670073 valid 1.546560247739156
# Training vs. Validation Loss {'Training': 1.5579851590670073, 'Validation': 1.546560247739156} 3
# Training vs. Validation accuracy {'Training': 0.38076546788215637, 'Validation': 0.4744027256965637} 3
# Epoch 3:
# Accuracy train:0.4553483724594116, val:0.4744027256965637
# LOSS train 1.519625654587379 valid 1.5100431243578594
# Training vs. Validation Loss {'Training': 1.519625654587379, 'Validation': 1.5100431243578594} 4
# Training vs. Validation accuracy {'Training': 0.4553483724594116, 'Validation': 0.4744027256965637} 4
# Epoch 4:
# Accuracy train:0.49852797389030457, val:0.4948805570602417
# LOSS train 1.4662318367224474 valid 1.4459264675776164
# Training vs. Validation Loss {'Training': 1.4662318367224474, 'Validation': 1.4459264675776164} 5
# Training vs. Validation accuracy {'Training': 0.49852797389030457, 'Validation': 0.4948805570602417} 5
# Epoch 5:
# Accuracy train:0.5387635231018066, val:0.49829351902008057
# LOSS train 1.3849231600761414 valid 1.3497550984223683
# Training vs. Validation Loss {'Training': 1.3849231600761414, 'Validation': 1.3497550984223683} 6
# Training vs. Validation accuracy {'Training': 0.5387635231018066, 'Validation': 0.49829351902008057} 6
# Epoch 6:
# Accuracy train:0.5780176520347595, val:0.49829351902008057
# LOSS train 1.2913292738107534 valid 1.2334623436133068
# Training vs. Validation Loss {'Training': 1.2913292738107534, 'Validation': 1.2334623436133068} 7
# Training vs. Validation accuracy {'Training': 0.5780176520347595, 'Validation': 0.49829351902008057} 7
# Epoch 7:
# Accuracy train:0.619234561920166, val:0.5255972743034363
# LOSS train 1.162689949457462 valid 1.1179482489824295
# Training vs. Validation Loss {'Training': 1.162689949457462, 'Validation': 1.1179482489824295} 8
# Training vs. Validation accuracy {'Training': 0.619234561920166, 'Validation': 0.5255972743034363} 8
# Epoch 8:
# Accuracy train:0.6418057084083557, val:0.5255972743034363
# LOSS train 1.0426803552187407 valid 0.9913614963491758
# Training vs. Validation Loss {'Training': 1.0426803552187407, 'Validation': 0.9913614963491758} 9
# Training vs. Validation accuracy {'Training': 0.6418057084083557, 'Validation': 0.5255972743034363} 9
# Epoch 9:
# Accuracy train:0.6712462902069092, val:0.5563139915466309
# LOSS train 0.9206748902797699 valid 0.8678076763947805
# Training vs. Validation Loss {'Training': 0.9206748902797699, 'Validation': 0.8678076763947805} 10
# Training vs. Validation accuracy {'Training': 0.6712462902069092, 'Validation': 0.5563139915466309} 10
# Epoch 10:
# Accuracy train:0.7006869316101074, val:0.6655290126800537
# LOSS train 0.7795219536011035 valid 0.7493251717338959
# Training vs. Validation Loss {'Training': 0.7795219536011035, 'Validation': 0.7493251717338959} 11
# Training vs. Validation accuracy {'Training': 0.7006869316101074, 'Validation': 0.6655290126800537} 11
# Epoch 11:
# Accuracy train:0.7242394685745239, val:0.7610921263694763
# LOSS train 0.6772369146347046 valid 0.6327350114782652
# Training vs. Validation Loss {'Training': 0.6772369146347046, 'Validation': 0.6327350114782652} 12
# Training vs. Validation accuracy {'Training': 0.7242394685745239, 'Validation': 0.7610921263694763} 12
# Epoch 12:
# Accuracy train:0.7968596816062927, val:0.8703071475028992
# LOSS train 0.6005906313657761 valid 0.5358709363887707
# Training vs. Validation Loss {'Training': 0.6005906313657761, 'Validation': 0.5358709363887707} 13
# Training vs. Validation accuracy {'Training': 0.7968596816062927, 'Validation': 0.8703071475028992} 13
# Epoch 13:
# Accuracy train:0.8577036261558533, val:0.9112628102302551
# LOSS train 0.5103068879017463 valid 0.43581792277594406
# Training vs. Validation Loss {'Training': 0.5103068879017463, 'Validation': 0.43581792277594406} 14
# Training vs. Validation accuracy {'Training': 0.8577036261558533, 'Validation': 0.9112628102302551} 14
# Epoch 14:
# Accuracy train:0.8842002153396606, val:0.9692832827568054
# LOSS train 0.44637542963027954 valid 0.3462604346374671
# Training vs. Validation Loss {'Training': 0.44637542963027954, 'Validation': 0.3462604346374671} 15
# Training vs. Validation accuracy {'Training': 0.8842002153396606, 'Validation': 0.9692832827568054} 15
# Epoch 15:
# Accuracy train:0.9097154140472412, val:0.9897611141204834
# LOSS train 0.39741318787519747 valid 0.27316295402124524
# Training vs. Validation Loss {'Training': 0.39741318787519747, 'Validation': 0.27316295402124524} 16
# Training vs. Validation accuracy {'Training': 0.9097154140472412, 'Validation': 0.9897611141204834} 16
# Epoch 16:
# Accuracy train:0.9381746649742126, val:0.9897611141204834
# LOSS train 0.3229883336103879 valid 0.19622404058463871
# Training vs. Validation Loss {'Training': 0.3229883336103879, 'Validation': 0.19622404058463871} 17
# Training vs. Validation accuracy {'Training': 0.9381746649742126, 'Validation': 0.9897611141204834} 17
# Epoch 17:
# Accuracy train:0.94700688123703, val:0.9931740760803223
# LOSS train 0.26843191797916705 valid 0.1386223757484307
# Training vs. Validation Loss {'Training': 0.26843191797916705, 'Validation': 0.1386223757484307} 18
# Training vs. Validation accuracy {'Training': 0.94700688123703, 'Validation': 0.9931740760803223} 18
# Epoch 18:
# Accuracy train:0.9421001076698303, val:0.9897611141204834
# LOSS train 0.2269290261543714 valid 0.1116425817211469
# Training vs. Validation Loss {'Training': 0.2269290261543714, 'Validation': 0.1116425817211469} 19
# Training vs. Validation accuracy {'Training': 0.9421001076698303, 'Validation': 0.9897611141204834} 19
# Epoch 19:
# Accuracy train:0.9744848012924194, val:0.9931740760803223
# LOSS train 0.17950181319163397 valid 0.07168096323342373
# Training vs. Validation Loss {'Training': 0.17950181319163397, 'Validation': 0.07168096323342373} 20
# Training vs. Validation accuracy {'Training': 0.9744848012924194, 'Validation': 0.9931740760803223} 20
# Epoch 20:
# Accuracy train:0.9725220799446106, val:0.9931740760803223
# LOSS train 0.16203340314901793 valid 0.058008546843969576
# Training vs. Validation Loss {'Training': 0.16203340314901793, 'Validation': 0.058008546843969576} 21
# Training vs. Validation accuracy {'Training': 0.9725220799446106, 'Validation': 0.9931740760803223} 21
# Epoch 21:
# Accuracy train:0.9764475226402283, val:0.9931740760803223
# LOSS train 0.14136132282706407 valid 0.04670126137595313
# Training vs. Validation Loss {'Training': 0.14136132282706407, 'Validation': 0.04670126137595313} 22
# Training vs. Validation accuracy {'Training': 0.9764475226402283, 'Validation': 0.9931740760803223} 22
# Epoch 22:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.12748986153075328 valid 0.038357764948159456
# Training vs. Validation Loss {'Training': 0.12748986153075328, 'Validation': 0.038357764948159456} 23
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 23
# Epoch 23:
# Accuracy train:0.98233562707901, val:0.9931740760803223
# LOSS train 0.10497809731616424 valid 0.035039496870012954
# Training vs. Validation Loss {'Training': 0.10497809731616424, 'Validation': 0.035039496870012954} 24
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9931740760803223} 24
# Epoch 24:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.09040909002606685 valid 0.03616436759087568
# Training vs. Validation Loss {'Training': 0.09040909002606685, 'Validation': 0.03616436759087568} 25
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 25
# Epoch 25:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.08631405377617249 valid 0.03559981005188698
# Training vs. Validation Loss {'Training': 0.08631405377617249, 'Validation': 0.03559981005188698} 26
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 26
# Epoch 26:
# Accuracy train:0.9793915748596191, val:0.9931740760803223
# LOSS train 0.07928816881030798 valid 0.029962454034830444
# Training vs. Validation Loss {'Training': 0.07928816881030798, 'Validation': 0.029962454034830444} 27
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9931740760803223} 27
# Epoch 27:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.06973828432651666 valid 0.029676258639180258
# Training vs. Validation Loss {'Training': 0.06973828432651666, 'Validation': 0.029676258639180258} 28
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 28
# Epoch 28:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.09044059541506264 valid 0.026508669046355255
# Training vs. Validation Loss {'Training': 0.09044059541506264, 'Validation': 0.026508669046355255} 29
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 29
# Epoch 29:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.07596599110043965 valid 0.026673155175861513
# Training vs. Validation Loss {'Training': 0.07596599110043965, 'Validation': 0.026673155175861513} 30
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 30
# Epoch 30:
# Accuracy train:0.983316957950592, val:0.9931740760803223
# LOSS train 0.06152135771341049 valid 0.024385127539668854
# Training vs. Validation Loss {'Training': 0.06152135771341049, 'Validation': 0.024385127539668854} 31
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9931740760803223} 31
# Epoch 31:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.056478575158577696 valid 0.023980133885440107
# Training vs. Validation Loss {'Training': 0.056478575158577696, 'Validation': 0.023980133885440107} 32
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 32
# Epoch 32:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.07086501317098737 valid 0.02669684650754789
# Training vs. Validation Loss {'Training': 0.07086501317098737, 'Validation': 0.02669684650754789} 33
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 33
# Epoch 33:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.06969231761132295 valid 0.023257586578741513
# Training vs. Validation Loss {'Training': 0.06969231761132295, 'Validation': 0.023257586578741513} 34
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 34
# Epoch 34:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.0536607436907406 valid 0.03164363462929032
# Training vs. Validation Loss {'Training': 0.0536607436907406, 'Validation': 0.03164363462929032} 35
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 35
# Epoch 35:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.06521611399232195 valid 0.02622508163161304
# Training vs. Validation Loss {'Training': 0.06521611399232195, 'Validation': 0.02622508163161304} 36
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 36
# Epoch 36:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.05511312408802601 valid 0.03011945755618702
# Training vs. Validation Loss {'Training': 0.05511312408802601, 'Validation': 0.03011945755618702} 37
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 37
# Epoch 37:
# Accuracy train:0.981354296207428, val:0.9931740760803223
# LOSS train 0.06960769318259107 valid 0.02579750279013145
# Training vs. Validation Loss {'Training': 0.06960769318259107, 'Validation': 0.02579750279013145} 38
# Training vs. Validation accuracy {'Training': 0.981354296207428, 'Validation': 0.9931740760803223} 38
# Epoch 38:
# Accuracy train:0.9892051219940186, val:0.9931740760803223
# LOSS train 0.04970708356883664 valid 0.02858273585540398
# Training vs. Validation Loss {'Training': 0.04970708356883664, 'Validation': 0.02858273585540398} 39
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931740760803223} 39
# Epoch 39:
# Accuracy train:0.9842983484268188, val:0.9931740760803223
# LOSS train 0.049698499067185015 valid 0.021083776434655494
# Training vs. Validation Loss {'Training': 0.049698499067185015, 'Validation': 0.021083776434655494} 40
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9931740760803223} 40
# Epoch 40:
# Accuracy train:0.9852796792984009, val:0.9931740760803223
# LOSS train 0.04906856992210333 valid 0.022497367585553246
# Training vs. Validation Loss {'Training': 0.04906856992210333, 'Validation': 0.022497367585553246} 41
# Training vs. Validation accuracy {'Training': 0.9852796792984009, 'Validation': 0.9931740760803223} 41
# Epoch 41:
# Accuracy train:0.9862610697746277, val:0.9931740760803223
# LOSS train 0.04734199915009622 valid 0.01908445706370306
# Training vs. Validation Loss {'Training': 0.04734199915009622, 'Validation': 0.01908445706370306} 42
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931740760803223} 42
# Epoch 42:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.04648593877657102 valid 0.019026170574458472
# Training vs. Validation Loss {'Training': 0.04648593877657102, 'Validation': 0.019026170574458472} 43
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 43
# Epoch 43:
# Accuracy train:0.9901864528656006, val:0.9931740760803223
# LOSS train 0.03170160102084852 valid 0.016759510003794276
# Training vs. Validation Loss {'Training': 0.03170160102084852, 'Validation': 0.016759510003794276} 44
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931740760803223} 44
# Epoch 44:
# Accuracy train:0.9872424006462097, val:0.9931740760803223
# LOSS train 0.03341830848680379 valid 0.018381227863452903
# Training vs. Validation Loss {'Training': 0.03341830848680379, 'Validation': 0.018381227863452903} 45
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9931740760803223} 45
# Epoch 45:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0

# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.01607480535032944 valid 0.022809579990356117
# Training vs. Validation Loss {'Training': 0.01607480535032944, 'Validation': 0.022809579990356117} 79
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 79
# Epoch 79:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.020391710571577557 valid 0.02135982570386356
# Training vs. Validation Loss {'Training': 0.020391710571577557, 'Validation': 0.02135982570386356} 80
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 80
# Epoch 80:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.027605396579019725 valid 0.0236529208139018
# Training vs. Validation Loss {'Training': 0.027605396579019725, 'Validation': 0.0236529208139018} 81
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 81
# Epoch 81:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.025122486068329845 valid 0.023757657277049777
# Training vs. Validation Loss {'Training': 0.025122486068329845, 'Validation': 0.023757657277049777} 82
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 82
# Epoch 82:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.016775980949974977 valid 0.0195859928416174
# Training vs. Validation Loss {'Training': 0.016775980949974977, 'Validation': 0.0195859928416174} 83
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 83
# Epoch 83:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.030570485190345116 valid 0.019871820306396632
# Training vs. Validation Loss {'Training': 0.030570485190345116, 'Validation': 0.019871820306396632} 84
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 84
# Epoch 84:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.01337377812664132 valid 0.022512274641447522
# Training vs. Validation Loss {'Training': 0.01337377812664132, 'Validation': 0.022512274641447522} 85
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 85
# Epoch 85:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.019444153308331106 valid 0.024247050790980513
# Training vs. Validation Loss {'Training': 0.019444153308331106, 'Validation': 0.024247050790980513} 86
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 86
# Epoch 86:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.020581450355866063 valid 0.020240297549264596
# Training vs. Validation Loss {'Training': 0.020581450355866063, 'Validation': 0.020240297549264596} 87
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 87
# Epoch 87:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.01657120075273829 valid 0.023477024082732594
# Training vs. Validation Loss {'Training': 0.01657120075273829, 'Validation': 0.023477024082732594} 88
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 88
# Epoch 88:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.022867159040358204 valid 0.02235964344237118
# Training vs. Validation Loss {'Training': 0.022867159040358204, 'Validation': 0.02235964344237118} 89
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 89
# Epoch 89:
# Accuracy train:0.9882237315177917, val:0.9931740760803223
# LOSS train 0.025328717803439267 valid 0.02286311098182144
# Training vs. Validation Loss {'Training': 0.025328717803439267, 'Validation': 0.02286311098182144} 90
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9931740760803223} 90
# Epoch 90:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.032571062490415685 valid 0.015496206328217946
# Training vs. Validation Loss {'Training': 0.032571062490415685, 'Validation': 0.015496206328217946} 91
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 91
# Epoch 91:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.021122800703429114 valid 0.016835204702488227
# Training vs. Validation Loss {'Training': 0.021122800703429114, 'Validation': 0.016835204702488227} 92
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 92
# Epoch 92:
# Accuracy train:0.9950932264328003, val:0.9965870380401611
# LOSS train 0.033608012178984396 valid 0.014357958200169682
# Training vs. Validation Loss {'Training': 0.033608012178984396, 'Validation': 0.014357958200169682} 93
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9965870380401611} 93
# Epoch 93:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.026186386812836505 valid 0.011656558438592887
# Training vs. Validation Loss {'Training': 0.026186386812836505, 'Validation': 0.011656558438592887} 94
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 94
# Epoch 94:
# Accuracy train:0.9892051219940186, val:0.9965870380401611
# LOSS train 0.02216728559981745 valid 0.015003175576756197
# Training vs. Validation Loss {'Training': 0.02216728559981745, 'Validation': 0.015003175576756197} 95
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9965870380401611} 95
# Epoch 95:
# Accuracy train:0.9941118955612183, val:0.9965870380401611
# LOSS train 0.019288301785798885 valid 0.01618683840039618
# Training vs. Validation Loss {'Training': 0.019288301785798885, 'Validation': 0.01618683840039618} 96
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 112
# Epoch 112:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.01346053459117404 valid 0.02884147750385561
# Training vs. Validation Loss {'Training': 0.01346053459117404, 'Validation': 0.02884147750385561} 113
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 113
# Epoch 113:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.015377120504406495 valid 0.02794377549391432
# Training vs. Validation Loss {'Training': 0.015377120504406495, 'Validation': 0.02794377549391432} 114
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 114
# Epoch 114:
# Accuracy train:0.9950932264328003, val:0.9897611141204834
# LOSS train 0.015031055475656804 valid 0.028297272772202103
# Training vs. Validation Loss {'Training': 0.015031055475656804, 'Validation': 0.028297272772202103} 115
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9897611141204834} 115
# Epoch 115:
# Accuracy train:0.9941118955612183, val:0.9931740760803223
# LOSS train 0.013820562871002879 valid 0.027825451858063843
# Training vs. Validation Loss {'Training': 0.013820562871002879, 'Validation': 0.027825451858063843} 116
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9931740760803223} 116
# Epoch 116:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.012174938283771133 valid 0.028588293323148644
# Training vs. Validation Loss {'Training': 0.012174938283771133, 'Validation': 0.028588293323148644} 117
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 117
# Epoch 117:
# Accuracy train:0.9941118955612183, val:0.9897611141204834
# LOSS train 0.02807038755585941 valid 0.03592215130133051
# Training vs. Validation Loss {'Training': 0.02807038755585941, 'Validation': 0.03592215130133051} 118
# Training vs. Validation accuracy {'Training': 0.9941118955612183, 'Validation': 0.9897611141204834} 118
# Epoch 118:
# Accuracy train:0.9931305050849915, val:0.9897611141204834
# LOSS train 0.024130601852308385 valid 0.031244900743918908
# Training vs. Validation Loss {'Training': 0.024130601852308385, 'Validation': 0.031244900743918908} 119
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9897611141204834} 119
# Epoch 119:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.012513818201394035 valid 0.02652097385578145
# Training vs. Validation Loss {'Training': 0.012513818201394035, 'Validation': 0.02652097385578145} 120
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 120
# Epoch 120:
# Accuracy train:0.9931305050849915, val:0.9931740760803223
# LOSS train 0.012630562240911577 valid 0.028754326732344754
# Training vs. Validation Loss {'Training': 0.012630562240911577, 'Validation': 0.028754326732344754} 121
# Training vs. Validation accuracy {'Training': 0.9931305050849915, 'Validation': 0.9931740760803223} 121
# Epoch 121:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.013085310947364913 valid 0.02906954890530263
# Training vs. Validation Loss {'Training': 0.013085310947364913, 'Validation': 0.02906954890530263} 122
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 122
# Epoch 122:
# Accuracy train:0.9970559477806091, val:0.9931740760803223
# LOSS train 0.015038226641571293 valid 0.026840240118332304
# Training vs. Validation Loss {'Training': 0.015038226641571293, 'Validation': 0.026840240118332304} 123
# Training vs. Validation accuracy {'Training': 0.9970559477806091, 'Validation': 0.9931740760803223} 123
# Epoch 123:
# Accuracy train:0.9911677837371826, val:0.9931740760803223
# LOSS train 0.01775991841434286 valid 0.02869240919469007
# Training vs. Validation Loss {'Training': 0.01775991841434286, 'Validation': 0.02869240919469007} 124
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9931740760803223} 124
# Epoch 124:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.015153066331269937 valid 0.02925142889739618
# Training vs. Validation Loss {'Training': 0.015153066331269937, 'Validation': 0.02925142889739618} 125
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 125
# Epoch 125:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.018782055556165196 valid 0.030358654094186477
# Training vs. Validation Loss {'Training': 0.018782055556165196, 'Validation': 0.030358654094186477} 126
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 126
# Epoch 126:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.025997188875827797 valid 0.02721718881379805
# Training vs. Validation Loss {'Training': 0.025997188875827797, 'Validation': 0.02721718881379805} 127
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 127
# Epoch 127:
# Accuracy train:0.9980372786521912, val:0.9931740760803223
# LOSS train 0.011597571193795795 valid 0.02746321794270064
# Training vs. Validation Loss {'Training': 0.011597571193795795, 'Validation': 0.02746321794270064} 128
# Training vs. Validation accuracy {'Training': 0.9980372786521912, 'Validation': 0.9931740760803223} 128
# Epoch 128:
# Accuracy train:0.9921491742134094, val:0.9931740760803223
# LOSS train 0.008830820680416834 valid 0.02700752249747514
# Training vs. Validation Loss {'Training': 0.008830820680416834, 'Validation': 0.02700752249747514} 129
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931740760803223} 129
# Epoch 129:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.012422427848482935 valid 0.024903292537042414
# Training vs. Validation Loss {'Training': 0.012422427848482935, 'Validation': 0.024903292537042414} 130
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 130
# Epoch 130:
# Accuracy train:0.9950932264328003, val:0.9931740760803223
# LOSS train 0.012095567094197927 valid 0.03128067279939728
# Training vs. Validation Loss {'Training': 0.012095567094197927, 'Validation': 0.03128067279939728} 131
# Training vs. Validation accuracy {'Training': 0.9950932264328003, 'Validation': 0.9931740760803223} 131
# Epoch 131:
# Accuracy train:0.9960745573043823, val:0.9931740760803223
# LOSS train 0.016165807655152794 valid 0.03227128553988715
# Training vs. Validation Loss {'Training': 0.016165807655152794, 'Validation': 0.03227128553988715} 132
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9931740760803223} 132
# Epoch 132:
# Accuracy train:0.9960745573043823, val:0.9897611141204834
# LOSS train 0.02509261742390943 valid 0.030520751863775786
# Training vs. Validation Loss {'Training': 0.02509261742390943, 'Validation': 0.030520751863775786} 133
# Training vs. Validation accuracy {'Training': 0.9960745573043823, 'Validation': 0.9897611141204834} 133
# stopping at epoch 132, minimum: 0.010488233805100814
# tensor(0.9898)

# %%
list_label = label_dict_from_config_file("hand_gesture.yaml")
DATA_FOLDER_PATH = "./data/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH, "landmark_test.csv"))

# Test DataLoader instantiation
################## Your Code Here ################## Q6
""" Hoàn thành code bên dưới để  khởi tạo DataLoader cho testset with batch size
20, không cho phép shuffle
"""
test_loader = torch.utils.data.DataLoader(testset, batch_size=20, shuffle=False)
####################################################


network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task="MULTICLASS")
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    ################## Your Code Here ################## Q7
    """Hoàn thành code bên dưới để  predict class của cử chỉ và update accuracy
    với kết quả predict và true labels
    """
    preds = network(test_input)
    acc_test.update(preds, test_label)

    ####################################################

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.9763779640197754
# ========================================================================
